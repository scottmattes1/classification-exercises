# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier as rfc
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.tree import export_graphviz
from sklearn.metrics import ConfusionMatrixDisplay


import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import pandas as pd
from pydataset import data

import prepare
import acquire

# %%
# acquire the data
df = acquire.get_titanic_data()
df
# Out:
#      Unnamed: 0  passenger_id  survived  pclass     sex   age  sibsp  parch  \
# 0             0             0         0       3    male  22.0      1      0
# 1             1             1         1       1  female  38.0      1      0
# 2             2             2         1       3  female  26.0      0      0
# 3             3             3         1       1  female  35.0      1      0
# 4             4             4         0       3    male  35.0      0      0
# ..          ...           ...       ...     ...     ...   ...    ...    ...
# 886         886           886         0       2    male  27.0      0      0
# 887         887           887         1       1  female  19.0      0      0
# 888         888           888         0       3  female   NaN      1      2
# 889         889           889         1       1    male  26.0      0      0
# 890         890           890         0       3    male  32.0      0      0
#
#         fare embarked   class deck  embark_town  alone
# 0     7.2500        S   Third  NaN  Southampton      0
# 1    71.2833        C   First    C    Cherbourg      0
# 2     7.9250        S   Third  NaN  Southampton      1
# 3    53.1000        S   First    C  Southampton      0
# 4     8.0500        S   Third  NaN  Southampton      1
# ..       ...      ...     ...  ...          ...    ...
# 886  13.0000        S  Second  NaN  Southampton      1
# 887  30.0000        S   First    B  Southampton      1
# 888  23.4500        S   Third  NaN  Southampton      0
# 889  30.0000        C   First    C    Cherbourg      1
# 890   7.7500        Q   Third  NaN   Queenstown      1
#
# [891 rows x 14 columns]

# %%
# split into train, test, and validate sections
train, validate, test = prepare.prep_titanic_data(df)

train.shape, validate.shape, test.shape
# Out:
# ((498, 11), (214, 11), (179, 11))

# %%
X_train = train.drop(columns=["survived"])
y_train = train.survived

X_validate = validate.drop(columns=["survived"])
y_validate = validate.survived

X_test = test.drop(columns=["survived"])
y_test = test.survived

# %%
# display head of df for reference
train.head(2)
# Out:
#      Unnamed: 0  survived  pclass   age  sibsp  parch    fare  alone  \
# 583         583         0       1  36.0      0      0  40.125      1
# 165         165         1       3   9.0      0      2  20.525      0
#
#      sex_male  embark_town_Queenstown  embark_town_Southampton
# 583         1                       0                        0
# 165         1                       0                        1

# %%
#create a baseline prediction
baseline = y_train.mode()

# %%
#test the baseline model accuracy
matches_baseline = y_train == 0
matches_baseline.shape
# Out:
# (498,)

# %%
baseline_accuracy = matches_baseline.mean()
print(f'Baseline accuracy is {baseline_accuracy}')
# Out:
# Baseline accuracy is 0.6164658634538153

# %%
# initiate a random forest model
rf = rfc(min_samples_leaf=1, max_depth=10, random_state=123)

# %%
# fit the model
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, random_state=123)

# %%
rf.classes_
# Out:
# array([0, 1])

# %%
# Make predictions with the model
y_pred = rf.predict(X_train)

# %%
# classification report
scores = classification_report(y_train, y_pred, output_dict=True)
pd.DataFrame(scores).T
# Out:
#               precision    recall  f1-score     support
# 0              0.965409  1.000000  0.982400  307.000000
# 1              1.000000  0.942408  0.970350  191.000000
# accuracy       0.977912  0.977912  0.977912    0.977912
# macro avg      0.982704  0.971204  0.976375  498.000000
# weighted avg   0.978676  0.977912  0.977779  498.000000

# %%
rf.score
# Out:
# <bound method ClassifierMixin.score of RandomForestClassifier(max_depth=10, random_state=123)>

# %%
# confusion matrix
conf = pd.DataFrame(confusion_matrix(y_pred, y_train))
conf
# Out:
#      0    1
# 0  307   11
# 1    0  180

# %%
# store values of negatives and positives
TP, TN, FP, FN = confusion_matrix(y_train, y_pred).ravel()

# %%
TP, TN, FP, FN
# Out:
# (307, 0, 11, 180)

# %%
all_pos_neg = TP + TN + FP + FN

# %%
accuracy = (TP + TN)/all_pos_neg
t_pos_rate = TP/(TP+FN)
f_pos_rate = FN/(FN+TP)
precision = TP/(TP+FP)
recall = TP/(TP+FN)
f1_score = 2 * (precision*recall)/(precision+recall)
support_pos = TP + FN
support_neg = FP + TN

# %%
print(f'''
Accuracy = {accuracy}
True Positive Rate = {t_pos_rate}
False Positive Rate = {f_pos_rate}
Precision = {precision}
Recall = {recall}
F1 Score = {f1_score}
Positive Support = {support_pos}
Negative Support = {support_neg}
''')
# Out:
# Accuracy = 0.6164658634538153
# True Positive Rate = 0.76010101010101
# False Positive Rate = 0.2398989898989899
# Precision = 0.7581863979848866
# Recall = 0.76010101010101
# F1 Score = 0.759142496847415
# Positive Support = 396
# Negative Support = 102

# %%
# initiate a random forest model
rf = rfc(min_samples_leaf=5, max_depth=2, random_state=123)

# fit the model
rf.fit(X_train, y_train)

rf.classes_

# Make predictions with the model
y_pred = rf.predict(X_train)

# classification report
scores = classification_report(y_train, y_pred, output_dict=True)
pd.DataFrame(scores).T

rf.score

# confusion matrix
conf = pd.DataFrame(confusion_matrix(y_pred, y_train))
conf

# store values of negatives and positives
TP, TN, FP, FN = confusion_matrix(y_train, y_pred).ravel()

TP, TN, FP, FN

all_pos_neg = TP + TN + FP + FN

accuracy = (TP + TN)/all_pos_neg
t_pos_rate = TP/(TP+FN)
f_pos_rate = FN/(FN+TP)
precision = TP/(TP+FP)
recall = TP/(TP+FN)
f1_score = 2 * (precision*recall)/(precision+recall)
support_pos = TP + FN
support_neg = FP + TN

print(f'''
Accuracy = {accuracy}
True Positive Rate = {t_pos_rate}
False Positive Rate = {f_pos_rate}
Precision = {precision}
Recall = {recall}
F1 Score = {f1_score}
Positive Support = {support_pos}
Negative Support = {support_neg}
''')
# Out:
# Accuracy = 0.6164658634538153
# True Positive Rate = 0.7279596977329975
# False Positive Rate = 0.27204030226700254
# Precision = 0.7768817204301075
# Recall = 0.7279596977329975
# F1 Score = 0.7516254876462939
# Positive Support = 397
# Negative Support = 101

# %% [markdown]
# true positive rate decreased and false negative increased
# precision increased and recall decreased
#
# both are at 61.6% accuracy so they both perform the same if that is the
# most important evaluation metric for the project

# %%
  for i in range(1,11):  
    # initiate a random forest model
    rf = rfc(min_samples_leaf=i, max_depth=5, random_state=123)

    # fit the model
    rf.fit(X_train, y_train)

    # Make predictions with the model
    y_pred = rf.predict(X_train)

    # classification report
    scores = classification_report(y_train, y_pred, output_dict=True)
    pd.DataFrame(scores).T


    # confusion matrix
    conf = pd.DataFrame(confusion_matrix(y_pred, y_train))
    conf

    # store values of negatives and positives
    TP, TN, FP, FN = confusion_matrix(y_train, y_pred).ravel()

    TP, TN, FP, FN

    all_pos_neg = TP + TN + FP + FN

    accuracy = (TP + TN)/all_pos_neg
    t_pos_rate = TP/(TP+FN)
    f_pos_rate = FN/(FN+TP)
    precision = TP/(TP+FP)
    recall = TP/(TP+FN)
    f1_score = 2 * (precision*recall)/(precision+recall)
    support_pos = TP + FN
    support_neg = FP + TN

    print(f'''
    min_samples_leaf = {i}
    
    Accuracy = {accuracy}
    True Positive Rate = {t_pos_rate}
    False Positive Rate = {f_pos_rate}
    Precision = {precision}
    Recall = {recall}
    F1 Score = {f1_score}
    Positive Support = {support_pos}
    Negative Support = {support_neg}
    
    -----------------------------------
    ''')
# Out:
#   min_samples_leaf = 1
#
#   Accuracy = 0.6164658634538153
#   True Positive Rate = 0.6842105263157895
#   False Positive Rate = 0.3157894736842105
#   Precision = 0.8494318181818182
#   Recall = 0.6842105263157895
#   F1 Score = 0.7579214195183778
#   Positive Support = 437
#   Negative Support = 61
#
#   -----------------------------------
#
#
#   min_samples_leaf = 2
#
#   Accuracy = 0.6164658634538153
#   True Positive Rate = 0.6773455377574371
#   False Positive Rate = 0.32265446224256294
#   Precision = 0.8554913294797688
#   Recall = 0.6773455377574371
#   F1 Score = 0.7560664112388251
#   Positive Support = 437
#   Negative Support = 61
#
#   -----------------------------------
#
#
#   min_samples_leaf = 3
#
#   Accuracy = 0.6164658634538153
#   True Positive Rate = 0.6851851851851852
#   False Positive Rate = 0.3148148148148148
#   Precision = 0.8433048433048433
#   Recall = 0.6851851851851852
#   F1 Score = 0.7560664112388251
#   Positive Support = 432
#   Negative Support = 66
#
#   -----------------------------------
#
#
#   min_samples_leaf = 4
#
#   Accuracy = 0.6164658634538153
#   True Positive Rate = 0.6834862385321101
#   False Positive Rate = 0.3165137614678899
#   Precision = 0.8490028490028491
#   Recall = 0.6834862385321101
#   F1 Score = 0.7573062261753494
#   Positive Support = 436
#   Negative Support = 62
#
#   -----------------------------------
#
#
#   min_samples_leaf = 5
#
#   Accuracy = 0.6164658634538153
#   True Positive Rate = 0.6869158878504673
#   False Positive Rate = 0.3130841121495327
#   Precision = 0.8376068376068376
#   Recall = 0.6869158878504673
#   F1 Score = 0.7548138639281129
#   Positive Support = 428
#   Negative Support = 70
#
#   -----------------------------------
#
#
#   min_samples_leaf = 6
#
#   Accuracy = 0.6164658634538153
#   True Positive Rate = 0.6869158878504673
#   False Positive Rate = 0.3130841121495327
#   Precision = 0.8376068376068376
#   Recall = 0.6869158878504673
#   F1 Score = 0.7548138639281129
#   Positive Support = 428
#   Negative Support = 70
#
#   -----------------------------------
#
#
#   min_samples_leaf = 7
#
#   Accuracy = 0.6164658634538153
#   True Positive Rate = 0.6853146853146853
#   False Positive Rate = 0.3146853146853147
#   Precision = 0.84
#   Recall = 0.6853146853146853
#   F1 Score = 0.7548138639281129
#   Positive Support = 429
#   Negative Support = 69
#
#   -----------------------------------
#
#
#   min_samples_leaf = 8
#
#   Accuracy = 0.6164658634538153
#   True Positive Rate = 0.6901408450704225
#   False Positive Rate = 0.30985915492957744
#   Precision = 0.8328611898016998
#   Recall = 0.6901408450704225
#   F1 Score = 0.754813863928113
#   Positive Support = 426
#   Negative Support = 72
#
#   -----------------------------------
#
#
#   min_samples_leaf = 9
#
#   Accuracy = 0.6164658634538153
#   True Positive Rate = 0.6933962264150944
#   False Positive Rate = 0.30660377358490565
#   Precision = 0.828169014084507
#   Recall = 0.6933962264150944
#   F1 Score = 0.754813863928113
#   Positive Support = 424
#   Negative Support = 74
#
#   -----------------------------------
#
#
#   min_samples_leaf = 10
#
#   Accuracy = 0.6164658634538153
#   True Positive Rate = 0.6879432624113475
#   False Positive Rate = 0.3120567375886525
#   Precision = 0.8314285714285714
#   Recall = 0.6879432624113475
#   F1 Score = 0.7529107373868047
#   Positive Support = 423
#   Negative Support = 75
#
#   -----------------------------------

# %%
for i in range(1,11):  
    # initiate a random forest model
    rf = rfc(min_samples_leaf=5, max_depth=i, random_state=123)

    # fit the model
    rf.fit(X_train, y_train)

    # Make predictions with the model
    y_pred = rf.predict(X_train)

    # classification report
    scores = classification_report(y_train, y_pred, output_dict=True)
    pd.DataFrame(scores).T

    rf.score

    # confusion matrix
    conf = pd.DataFrame(confusion_matrix(y_pred, y_train))
    conf

    # store values of negatives and positives
    TP, TN, FP, FN = confusion_matrix(y_train, y_pred).ravel()

    TP, TN, FP, FN

    all_pos_neg = TP + TN + FP + FN

    accuracy = (TP + TN)/all_pos_neg
    t_pos_rate = TP/(TP+FN)
    f_pos_rate = FN/(FN+TP)
    precision = TP/(TP+FP)
    recall = TP/(TP+FN)
    f1_score = 2 * (precision*recall)/(precision+recall)
    support_pos = TP + FN
    support_neg = FP + TN

    print(f'''
    max_depth = {i}
    
    Accuracy = {accuracy}
    True Positive Rate = {t_pos_rate}
    False Positive Rate = {f_pos_rate}
    Precision = {precision}
    Recall = {recall}
    F1 Score = {f1_score}
    Positive Support = {support_pos}
    Negative Support = {support_neg}
    
    -----------------------------------
    ''')
# Out:
#     max_depth = 1
#
#     Accuracy = 0.6164658634538153
#     True Positive Rate = 0.76010101010101
#     False Positive Rate = 0.2398989898989899
#     Precision = 0.7581863979848866
#     Recall = 0.76010101010101
#     F1 Score = 0.759142496847415
#     Positive Support = 396
#     Negative Support = 102
#
#     -----------------------------------
#
#
#     max_depth = 2
#
#     Accuracy = 0.6164658634538153
#     True Positive Rate = 0.7279596977329975
#     False Positive Rate = 0.27204030226700254
#     Precision = 0.7768817204301075
#     Recall = 0.7279596977329975
#     F1 Score = 0.7516254876462939
#     Positive Support = 397
#     Negative Support = 101
#
#     -----------------------------------
#
#
#     max_depth = 3
#
#     Accuracy = 0.6164658634538153
#     True Positive Rate = 0.6900726392251816
#     False Positive Rate = 0.3099273607748184
#     Precision = 0.8189655172413793
#     Recall = 0.6900726392251816
#     F1 Score = 0.7490144546649146
#     Positive Support = 413
#     Negative Support = 85
#
#     -----------------------------------
#
#
#     max_depth = 4
#
#     Accuracy = 0.6164658634538153
#     True Positive Rate = 0.6863207547169812
#     False Positive Rate = 0.3136792452830189
#     Precision = 0.833810888252149
#     Recall = 0.6863207547169812
#     F1 Score = 0.7529107373868047
#     Positive Support = 424
#     Negative Support = 74
#
#     -----------------------------------
#
#
#     max_depth = 5
#
#     Accuracy = 0.6164658634538153
#     True Positive Rate = 0.6869158878504673
#     False Positive Rate = 0.3130841121495327
#     Precision = 0.8376068376068376
#     Recall = 0.6869158878504673
#     F1 Score = 0.7548138639281129
#     Positive Support = 428
#     Negative Support = 70
#
#     -----------------------------------
#
#
#     max_depth = 6
#
#     Accuracy = 0.6164658634538153
#     True Positive Rate = 0.6765375854214123
#     False Positive Rate = 0.3234624145785877
#     Precision = 0.8583815028901735
#     Recall = 0.6765375854214123
#     F1 Score = 0.756687898089172
#     Positive Support = 439
#     Negative Support = 59
#
#     -----------------------------------
#
#
#     max_depth = 7
#
#     Accuracy = 0.6164658634538153
#     True Positive Rate = 0.6772727272727272
#     False Positive Rate = 0.32272727272727275
#     Precision = 0.8587896253602305
#     Recall = 0.6772727272727272
#     F1 Score = 0.7573062261753494
#     Positive Support = 440
#     Negative Support = 58
#
#     -----------------------------------
#
#
#     max_depth = 8
#
#     Accuracy = 0.6164658634538153
#     True Positive Rate = 0.6644144144144144
#     False Positive Rate = 0.3355855855855856
#     Precision = 0.8753709198813057
#     Recall = 0.6644144144144144
#     F1 Score = 0.7554417413572343
#     Positive Support = 444
#     Negative Support = 54
#
#     -----------------------------------
#
#
#     max_depth = 9
#
#     Accuracy = 0.6164658634538153
#     True Positive Rate = 0.6636771300448431
#     False Positive Rate = 0.336322869955157
#     Precision = 0.8783382789317508
#     Recall = 0.6636771300448431
#     F1 Score = 0.756066411238825
#     Positive Support = 446
#     Negative Support = 52
#
#     -----------------------------------
#
#
#     max_depth = 10
#
#     Accuracy = 0.6164658634538153
#     True Positive Rate = 0.6681715575620768
#     False Positive Rate = 0.33182844243792325
#     Precision = 0.8705882352941177
#     Recall = 0.6681715575620768
#     F1 Score = 0.7560664112388251
#     Positive Support = 443
#     Negative Support = 55
#
#     -----------------------------------

# %%
metrics = []

for i in range(2, 21):
    forest = rfc(min_samples_leaf= 5, max_depth=i, random_state=123)

    forest = forest.fit(X_train, y_train)

    train_accuracy = forest.score(X_train, y_train)
    
    validate_accuracy = forest.score(X_validate, y_validate)

    output = {
        "max_depth": i,
        "train_accuracy": train_accuracy,
        "validate_accuracy": validate_accuracy
    }
    
    metrics.append(output)
    
df = pd.DataFrame(metrics)
df["difference"] = df.train_accuracy - df.validate_accuracy
df
# Out:
#     max_depth  train_accuracy  validate_accuracy  difference
# 0           2        0.797189           0.785047    0.012142
# 1           3        0.829317           0.789720    0.039598
# 2           4        0.851406           0.794393    0.057013
# 3           5        0.859438           0.803738    0.055699
# 4           6        0.881526           0.785047    0.096479
# 5           7        0.883534           0.808411    0.075123
# 6           8        0.891566           0.799065    0.092501
# 7           9        0.895582           0.803738    0.091844
# 8          10        0.889558           0.808411    0.081147
# 9          11        0.889558           0.803738    0.085820
# 10         12        0.891566           0.803738    0.087828
# 11         13        0.891566           0.803738    0.087828
# 12         14        0.889558           0.803738    0.085820
# 13         15        0.889558           0.803738    0.085820
# 14         16        0.889558           0.803738    0.085820
# 15         17        0.889558           0.803738    0.085820
# 16         18        0.889558           0.803738    0.085820
# 17         19        0.889558           0.803738    0.085820
# 18         20        0.889558           0.803738    0.085820

# %% [markdown]
# max_depth= 2 has the closest train and validate accuracy
